# %%
import numpy as np
import pandas as pd
import matplotlib 
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel(r'C:\Users\Imad\Desktop\Absent.xls')
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
df_test = [['Son','Pet','Absenteeism time in hours']]

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df = df.replace('?', np.nan)
df.dtypes
# Out:
# ID                                 int64
# Reason for absence                 int64
# Month of absence                   int64
# Day of the week                    int64
# Seasons                            int64
# Transportation expense             int64
# Distance from Residence to Work    int64
# Service time                       int64
# Age                                int64
# Work load Average/day              int64
# Hit target                         int64
# Disciplinary failure               int64
# Education                          int64
# Son                                int64
# Social drinker                     int64
# Social smoker                      int64
# Pet                                int64
# Weight                             int64
# Height                             int64
# Body mass index                    int64
# Absenteeism time in hours          int64
# dtype: object

# %%
df.corr()
# Out:
#                                        ID  Reason for absence  \
# ID                               1.000000           -0.064245
# Reason for absence              -0.064245            1.000000
# Month of absence                -0.000043           -0.083858
# Day of the week                  0.034468            0.116319
# Seasons                          0.098495           -0.117925
# Transportation expense          -0.224163           -0.119381
# Distance from Residence to Work -0.486160            0.161831
# Service time                    -0.272704            0.048425
# Age                              0.040899           -0.078608
# Work load Average/day            0.092457           -0.123472
# Hit target                       0.018789            0.088943
# Disciplinary failure             0.004502           -0.545054
# Education                       -0.036254           -0.047357
# Son                              0.002767           -0.055364
# ...

# %%
df['Son'].value_counts()
# Out:
# 0    298
# 1    229
# 2    156
# 4     42
# 3     15
# Name: Son, dtype: int64

# %%
sns.boxplot(x='Son',y='Absenteeism time in hours', data=df)

# %% [markdown]
# # Data Transformation and rescaling

# %%
df_input = df.drop(['ID','Work load Average/day','Absenteeism time in hours'], axis = 'columns')
df_target =df['Absenteeism time in hours']

# %%
X = np.asarray(df_input)
y = np.asarray(df_target)

# %%
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler(feature_range=(0,1))
X_scale = scalar.fit_transform(X)
X_scale

# %%
X[:5]

# %%
X[:,0].std()

# %%
from sklearn.preprocessing import StandardScaler
sscalar = StandardScaler()
X_scale=sscalar.fit_transform(X)

# %%
X_scale[:,6].std()

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# %%
sm=SelectKBest(score_func=f_regression,k=6)

# %%
smfit=sm.fit(df_input,df_target)

# %%
smfit.scores_
# Out:
# array([22.80042616,  0.43766935, 11.59287528,  0.02326841,  0.56198058,
#         5.80764136,  0.26733604,  3.20522214,  0.52629339, 11.57155705,
#         1.58099924,  9.67532263,  3.1377989 ,  0.05894114,  0.59055152,
#         0.18402787, 15.72055599,  1.82887666])

# %%
smfit.transform(df_input)
# Out:
# array([[ 26,   3,  36,   0,   2, 172],
#        [  0,   3,  13,   1,   1, 178],
#        [ 23,   4,  51,   0,   0, 170],
#        ...,
#        [  0,   3,  14,   0,   1, 170],
#        [  0,   4,  35,   0,   2, 170],
#        [  0,   6,  45,   0,   1, 175]], dtype=int64)

# %%
df_input.head()
# Out:
#    Reason for absence  Month of absence  Day of the week  Seasons  \
# 0                  26                 7                3        1
# 1                   0                 7                3        1
# 2                  23                 7                4        1
# 3                   7                 7                5        1
# 4                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Hit target  Disciplinary failure  Education  Son  Social drinker  \
# ...

# %%
df_input=df_input.sort_values(['Age'])

# %% [markdown]
# # Recursive Feature Selection

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
rf=RFE(LogisticRegression(), n_features_to_select=7)

# %%
rf.fit(df_input,df_target)

# %%
rf.ranking_

# %%
df_input.head()

# %%
rf.support_

# %%
rf.transform(df_input)

# %% [markdown]
# # PCA

# %%
df = np.asarray(df)
from sklearn.preprocessing import StandardScaler

# %%
X = StandardScaler().fit(df).transform(df)
X[0:5]
# Out:
# C:\Users\Imad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Imad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[-0.63716146,  0.80493838,  0.19676258, -0.64394734, -1.3901746 ,
#          1.01140838,  0.42955567,  0.10176977, -0.53286845, -0.81821241,
#          0.63868581, -0.23904572, -0.43385741,  0.89372277,  0.87287156,
#         -0.28056586,  0.19284983,  0.85167289, -0.01904601,  0.77593223,
#         -0.21951111],
#        [ 1.63271857, -2.28012426,  0.19676258, -0.64394734, -1.3901746 ,
#         -1.54437915, -1.12169354,  1.24282479,  2.09286015, -0.81821241,
#          0.63868581,  4.18330013, -0.43385741, -0.01723432,  0.87287156,
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
x_pca = pca.fit(X)

# %%
x_pca
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
x_pca.components_
# Out:
# array([[-0.2146978 ,  0.035994  ,  0.01521115, -0.03944523, -0.02931753,
#         -0.13202843,  0.11779256,  0.41913054,  0.3458314 , -0.04165957,
#         -0.05702784,  0.03402913, -0.25277907, -0.03658264,  0.33263603,
#         -0.07802724, -0.16671632,  0.44390352,  0.01848695,  0.45813196,
#          0.01409147],
#        [-0.3085482 ,  0.00388979,  0.18058592,  0.07418741,  0.04702454,
#          0.47397038,  0.45878002, -0.12443914, -0.16442386, -0.04791634,
#         -0.14560955,  0.07389867, -0.19925466,  0.26689721,  0.2807221 ,
#          0.00318798,  0.31283281, -0.09355277, -0.24576131,  0.01057949,
#         -0.03116769]])

# %%
pca.explained_variance_
# Out:
# array([3.4489119, 2.4012205])

# %%
df_target.head(1)
# Out:
# 0    4
# Name: Absenteeism time in hours, dtype: int64

# %%
pca.transform(df)
# Out:
# array([[ -9946.99911577, -11397.55349373],
#        [ -9921.15874219, -11502.98018122],
#        [ -9925.12518243, -11441.91058366],
#        ...,
#        [-11239.0086316 , -13004.19851274],
#        [-11249.99880058, -12943.86510102],
#        [-11257.84680873, -12974.40443633]])
